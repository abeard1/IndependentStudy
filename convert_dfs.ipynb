# %% [markdown]
# ## Convert df_possible to df_actual

# %%
import pandas as pd

years = [2015, 2016, 2017]

for year in years:
    print(year)
    
    df_possible = pd.read_csv('df_possibles/possible_df_{}.csv'.format(year))
    
    print(len(df_possible[df_possible['times_played'] > 0]))
    
    df_actual = df_possible[df_possible['times_played'] > 0]
    
    # save csv
    file_name = 'df_actuals/df_actual_{}.csv'.format(year)
    df_actual.to_csv(file_name, index=False)
# Out:
# 2015
# 18799
# 2016
# 19100
# 2017
# 16833

# %%
for year in years:
    print(year)
    
    file_name = 'df_actuals/df_actual_{}.csv'.format(year)
    df_actual_test = pd.read_csv(file_name)
    
    print(len(df_actual_test))
    
    print(df_actual_test['defense'].unique())
# Out:
# 2015
# 18799
# ['Defense_aries-trikala' 'Defense_drama' 'Defense_aek-athens'
#  'Defense_koroivos' 'Defense_apollon-patras' 'Defense_olympiakos'
#  'Defense_nea-kifisia' 'Defense_panathinaikos' 'Defense_aris'
#  'Defense_panelefsiniakos' 'Defense_rhodes' 'Defense_panionios'
#  'Defense_rethymno' 'Defense_paok' 'Defense_villeurbanne' 'Defense_artland'
#  'Defense_cantu' 'Defense_gran-canaria' 'Defense_hapoel-jerusalem'
#  'Defense_banvitspor' 'Defense_olimpija-ljubljana' 'Defense_besiktas'
#  'Defense_strasbourg' 'Defense_bonn' 'Defense_oostende' 'Defense_dijon'
#  'Defense_karsiyaka' 'Defense_vef-riga' 'Defense_khimki' 'Defense_ploiesti'
#  'Defense_krasny-oktyabr' 'Defense_nymburk' 'Defense_nancy'
#  'Defense_sevilla' 'Defense_oldenburg' 'Defense_brose-baskets'
#  'Defense_reggio-emilia' 'Defense_roma' 'Defense_spirou'
#  'Defense_triumph-moscow' 'Defense_szolnoki-olaj' 'Defense_buducnost'
#  'Defense_ventspils' 'Defense_partizan' 'Defense_vilnius'
#  'Defense_paris-levallois' 'Defense_zaragoza' 'Defense_kuban'
#  'Defense_zielona-gora' 'Defense_valencia' 'Defense_bayern-muenchen'
#  'Defense_cedevita' 'Defense_limoges' 'Defense_neptunas' 'Defense_sassari'
#  'Defense_unics-kazan' 'Defense_turow' 'Defense_vitoria'
#  'Defense_barcelona' 'Defense_manresa' 'Defense_obradoiro'
#  'Defense_canarias' 'Defense_fuenlabrada' 'Defense_bilbao'
#  'Defense_san-sebastian' 'Defense_estudiantes' 'Defense_murcia'
#  'Defense_real-madrid' 'Defense_andorra' 'Defense_unicaja-malaga'
#  'Defense_joventut' 'Defense_milano' 'Defense_cremona' 'Defense_venezia'
#  'Defense_avellino' 'Defense_pesaro' 'Defense_brindisi' 'Defense_pistoia'
#  'Defense_orlandina' 'Defense_caserta' 'Defense_virtus-bologna'
#  'Defense_trento' 'Defense_varese' 'Defense_orleans' 'Defense_pau-orthez'
#  'Defense_le-havre' 'Defense_bourg' 'Defense_cholet' 'Defense_rouen'
#  'Defense_le-mans' 'Defense_chalon' 'Defense_nanterre' 'Defense_reims'
#  'Defense_gravelines' 'Defense_boulogne' 'Defense_anadolu-efes'
#  'Defense_maccabi-tel-aviv' 'Defense_galatasaray' 'Defense_red-star'
#  'Defense_cska-moscow' 'Defense_alba-berlin' 'Defense_novgorod'
#  'Defense_zalgiris' 'Defense_ulker-fenerbahce']
# 2016
# 19100
# ['Defense_paok' 'Defense_aek-athens' 'Defense_lavrio' 'Defense_kavala'
#  'Defense_aries-trikala' 'Defense_koroivos' 'Defense_apollon-patras'
#  'Defense_rethymno' 'Defense_panathinaikos' 'Defense_aris'
#  'Defense_arkadikos' 'Defense_nea-kifisia' 'Defense_rhodes'
#  'Defense_olympiakos' 'Defense_gran-canaria' 'Defense_le-mans'
#  'Defense_valencia' 'Defense_nancy' 'Defense_krasny-oktyabr'
#  'Defense_nanterre' 'Defense_bilbao' 'Defense_oldenburg' 'Defense_bonn'
#  'Defense_banvitspor' 'Defense_buducnost' 'Defense_alba-berlin'
#  'Defense_ludwigsburg' 'Defense_galatasaray' 'Defense_neptunas'
#  'Defense_hapoel-jerusalem' 'Defense_novgorod' 'Defense_trento'
#  'Defense_olimpija-ljubljana' 'Defense_szolnoki-olaj' 'Defense_brindisi'
#  'Defense_reggio-emilia' 'Defense_triumph-moscow' 'Defense_saratov'
#  'Defense_trabzonspor' 'Defense_venezia' 'Defense_ulm'
#  'Defense_steaua-csm-bucharest' 'Defense_unics-kazan' 'Defense_besiktas'
#  'Defense_vilnius' 'Defense_spirou' 'Defense_zaragoza' 'Defense_limoges'
#  'Defense_zielona-gora' 'Defense_sassari' 'Defense_milano'
#  'Defense_bayern-muenchen' 'Defense_strasbourg' 'Defense_karsiyaka'
#  'Defense_maccabi-tel-aviv' 'Defense_manresa' 'Defense_fuenlabrada'
#  'Defense_san-sebastian' 'Defense_canarias' 'Defense_joventut'
#  'Defense_andorra' 'Defense_barcelona' 'Defense_vitoria'
#  'Defense_estudiantes' 'Defense_unicaja-malaga' 'Defense_murcia'
#  'Defense_sevilla' 'Defense_obradoiro' 'Defense_real-madrid'
#  'Defense_pesaro' 'Defense_avellino' 'Defense_cantu' 'Defense_orlandina'
#  'Defense_pistoia' 'Defense_cremona' 'Defense_caserta' 'Defense_varese'
#  'Defense_virtus-bologna' 'Defense_turin' 'Defense_rouen'
#  'Defense_gravelines' 'Defense_le-havre' 'Defense_chalon' 'Defense_cholet'
#  'Defense_orleans' 'Defense_dijon' 'Defense_paris-levallois'
#  'Defense_chalons-en-champagne' 'Defense_pau-orthez' 'Defense_villeurbanne'
#  'Defense_monaco' 'Defense_antibes' 'Defense_cska-moscow'
#  'Defense_darussafaka' 'Defense_cedevita' 'Defense_red-star'
#  'Defense_brose-baskets' 'Defense_khimki' 'Defense_kuban'
#  'Defense_anadolu-efes' 'Defense_ulker-fenerbahce' 'Defense_zalgiris']
# 2017
# 16833
# ['Defense_aries-trikala' 'Defense_aris' 'Defense_paok' 'Defense_doxa-bc'
#  'Defense_olympiakos' 'Defense_koroivos' 'Defense_kymis-bc'
#  'Defense_lavrio' 'Defense_rethymno' 'Defense_rhodes' 'Defense_aek-athens'
#  'Defense_apollon-patras' 'Defense_promitheas' 'Defense_panathinaikos'
#  'Defense_fuenlabrada' 'Defense_alba-berlin' 'Defense_cedevita'
#  'Defense_gran-canaria' 'Defense_vilnius' 'Defense_khimki'
#  'Defense_mzt-skopje' 'Defense_lietkabelis' 'Defense_buducnost'
#  'Defense_murcia' 'Defense_kuban' 'Defense_olimpija-ljubljana'
#  'Defense_bayern-muenchen' 'Defense_triumph-moscow' 'Defense_ulm'
#  'Defense_valencia' 'Defense_novgorod' 'Defense_bilbao'
#  'Defense_unicaja-malaga' 'Defense_hapoel-jerusalem' 'Defense_real-madrid'
#  'Defense_sevilla' 'Defense_estudiantes' 'Defense_vitoria'
#  'Defense_obradoiro' 'Defense_canarias' 'Defense_barcelona'
#  'Defense_manresa' 'Defense_joventut' 'Defense_zaragoza' 'Defense_andorra'
#  'Defense_turin' 'Defense_avellino' 'Defense_trento' 'Defense_brindisi'
#  'Defense_venezia' 'Defense_cantu' 'Defense_reggio-emilia'
#  'Defense_caserta' 'Defense_milano' 'Defense_orlandina' 'Defense_pistoia'
#  'Defense_cremona' 'Defense_varese' 'Defense_sassari' 'Defense_pesaro'
#  'Defense_brescia' 'Defense_gravelines' 'Defense_hyeres-toulon'
#  'Defense_nanterre' 'Defense_le-portel' 'Defense_nancy'
#  'Defense_paris-levallois' 'Defense_orleans' 'Defense_chalon'
#  'Defense_antibes' 'Defense_chalons-en-champagne' 'Defense_cholet'
#  'Defense_pau-orthez' 'Defense_monaco' 'Defense_villeurbanne'
#  'Defense_strasbourg' 'Defense_le-mans' 'Defense_limoges' 'Defense_dijon'
#  'Defense_cska-moscow' 'Defense_galatasaray' 'Defense_maccabi-tel-aviv'
#  'Defense_darussafaka' 'Defense_red-star' 'Defense_zalgiris'
#  'Defense_brose-baskets' 'Defense_ulker-fenerbahce' 'Defense_unics-kazan'
#  'Defense_anadolu-efes']
